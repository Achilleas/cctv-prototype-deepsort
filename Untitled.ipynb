# %%
import plotly.express as px
from dash.dependencies import Input, Output, State
from plotly.graph_objs import *
import dash_html_components as html
import dash_core_components as dcc
from utils.app_utils import *
import plotly.graph_objects as go

import plotly.express as px

geojson = px.data.election_geojson()
df = px.data.election()

df.rename(columns={'Bergeron' : 'Occurences'})
df['Occurences'] = 0
df.at[2, 'Occurences'] = 3
df.at[5, 'Occurences'] = 5

df.loc[:, 'district'] = ['area_{}'.format(i) for i in range(len(df))]
df.at[2, 'district'] = 'cctv_1'
df.at[5, 'district'] = 'cctv_2'

for i, f in enumerate(geojson['features']):
    print(geojson['features'][i]['properties'])
    if i == 2:
        s = 'cctv_1'
    elif i == 5:
        s = 'cctv_2'
    else:
        s = 'area_{}'.format(i)
    geojson['features'][i]['properties']['district'] = s
    geojson['features'][i]['id'] = str(df.at[i, 'district_id'])
    print('after' ,geojson['features'][i]['properties'])
    
fig = px.choropleth(df, geojson=geojson, color="Occurences",
                    locations="district", featureidkey="properties.district",
                    projection="mercator", color_continuous_scale='Reds'
                   )

fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# {'district': '11-Sault-au-Récollet'}
# after {'district': 'area_0'}
# {'district': '12-Saint-Sulpice'}
# after {'district': 'area_1'}
# {'district': '13-Ahuntsic'}
# after {'district': 'cctv_1'}
# {'district': '14-Bordeaux-Cartierville'}
# after {'district': 'area_3'}
# {'district': '21-Ouest'}
# after {'district': 'area_4'}
# {'district': '22-Est'}
# after {'district': 'cctv_2'}
# {'district': '23-Centre'}
# after {'district': 'area_6'}
# {'district': '31-Darlington'}
# after {'district': 'area_7'}
# {'district': '32-Côte-des-Neiges'}
# after {'district': 'area_8'}
# {'district': '33-Snowdon'}
# after {'district': 'area_9'}
# {'district': '34-Notre-Dame-de-Grâce'}
# after {'district': 'area_10'}
# {'district': '35-Loyola'}
# after {'district': 'area_11'}
# {'district': '41-du Canal'}
# after {'district': 'area_12'}
# {'district': '42-J.-Émery-Provost'}
# after {'district': 'area_13'}
# {'district': '43-Fort-Rolland'}
# after {'district': 'area_14'}
# ...

# %%
df
#df.assign(0, 'district', range(880, 880 + len(df)))
# Out:
#    district  Coderre  Bergeron  Joly  total    winner     result  district_id
# 0    area_0     2481         0     0   7334      Joly  plurality          101
# 1    area_1     2525         0     0   6363      Joly  plurality          102
# 2    cctv_1     3348         3     0   8650   Coderre  plurality           11
# 3    area_3     1734         0     0   9030  Bergeron   majority          111
# 4    area_4     1770         0    10  10747  Bergeron   majority          112
# 5    cctv_2     1455         5     0   7370  Bergeron  plurality          113
# 6    area_6     3252         0     0   8316   Coderre  plurality           12
# 7    area_7     5456         0     0  10546   Coderre   majority          121
# 8    area_8     4734         0    30   9465   Coderre   majority          122
# 9    area_9     5737         0     0   8351   Coderre   majority          123
# 10  area_10     2979         0     0   9282  Bergeron  plurality           13
# ...

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-73.6363215300962, 45.5759177646435],
#        [-73.6362833815582, 45.5758266113331],
#        [-73.6446417578686, 45.5658132919643],
#        [-73.6453511352974, 45.5647725775888],
#        [-73.648867564748, 45.5586898267402],
#        [-73.6513170845065, 45.5545659435652],
#        [-73.6515658357324, 45.5554439857955],
#        [-73.6660837831645, 45.5596724837829],
#        [-73.6706609041685, 45.5610978251999],
#        [-73.6676019919116, 45.5632340862888],
#        [-73.6645385824068, 45.5642716484367],
#        [-73.663663123697, 45.5654269638586],
#        [-73.663336397858, 45.5666288247853],
#        [-73.6637764768649, 45.5678900619231],
#        [-73.6625073244826, 45.5688479494114],
#        [-73.6624620526633, 45.5708304456346],
#        [-73.6620201425015, 45.5713925326191],
#        [-73.6616100197742, 45.5737924780218],
# ...

# %%
df[5, 'district'] = 'cctv_2'

# %%
geojson['features'][2]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-73.6513170845065, 45.5545659435652],
#     [-73.6568659704249, 45.5450525873044],
#     [-73.6604302515405, 45.5460790656787],
#     [-73.6616100449503, 45.5441416421638],
#     [-73.662249203322, 45.543633408253],
#     [-73.6646235398403, 45.5394847807605],
#     [-73.664945183105, 45.5382590909533],
#     [-73.667891862525, 45.5387409623539],
#     [-73.6687347480061, 45.5363337408676],
#     [-73.6740837310465, 45.5378868187786],
#     [-73.6752852955733, 45.5369404343695],
#     [-73.6785046215606, 45.5379069417581],
#     [-73.6807721370907, 45.534331320177],
#     [-73.6920199187781, 45.5394683031028],
#     [-73.702520410412, 45.5431766227664],
#     [-73.7042065154565, 45.5438906316964],
#     [-73.7043014929187, 45.5441905861876],
#     [-73.7027027602765, 45.5451406840713],
#     [-73.7023335988111, 45.5457621950639],
#     [-73.7012226911876, 45.5459702396396],
# ...

# %%
import pandas
dff = pandas.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

# %%
dff
# Out:
#    code           state category  total exports   beef    pork  poultry  \
# 0    AL         Alabama    state        1390.63   34.4    10.6    481.0
# 1    AK          Alaska    state          13.31    0.2     0.1      0.0
# 2    AZ         Arizona    state        1463.17   71.3    17.9      0.0
# 3    AR        Arkansas    state        3586.02   53.2    29.4    562.9
# 4    CA      California    state       16472.88  228.7    11.1    225.4
# 5    CO        Colorado    state        1851.33  261.4    66.0     14.0
# 6    CT     Connecticut    state         259.62    1.1     0.1      6.9
# 7    DE        Delaware    state         282.19    0.4     0.6    114.7
# 8    FL         Florida    state        3764.09   42.6     0.9     56.9
# 9    GA         Georgia    state        2860.84   31.0    18.9    630.4
# 10   HI          Hawaii    state         401.84    4.0     0.7      1.3
# 11   ID           Idaho    state        2078.89  119.8     0.0      2.4
# ...

# %%
columns=[{'name': i, 'id': i} for i in df.columns]
columns
# Out:
# [{'name': 'State', 'id': 'State'},
#  {'name': 'Number of Solar Plants', 'id': 'Number of Solar Plants'},
#  {'name': 'Installed Capacity (MW)', 'id': 'Installed Capacity (MW)'},
#  {'name': 'Average MW Per Plant', 'id': 'Average MW Per Plant'},
#  {'name': 'Generation (GWh)', 'id': 'Generation (GWh)'}]

# %%
df.to_dict('records')
# Out:
# [{'State': 'California',
#   'Number of Solar Plants': 289,
#   'Installed Capacity (MW)': 4395,
#   'Average MW Per Plant': 15.3,
#   'Generation (GWh)': 10826},
#  {'State': 'Arizona',
#   'Number of Solar Plants': 48,
#   'Installed Capacity (MW)': 1078,
#   'Average MW Per Plant': 22.5,
#   'Generation (GWh)': 2550},
#  {'State': 'Nevada',
#   'Number of Solar Plants': 11,
#   'Installed Capacity (MW)': 238,
#   'Average MW Per Plant': 21.6,
#   'Generation (GWh)': 557},
#  {'State': 'New Mexico',
#   'Number of Solar Plants': 33,
#   'Installed Capacity (MW)': 261,
#   'Average MW Per Plant': 7.9,
#   'Generation (GWh)': 590},
#  {'State': 'Colorado',
#   'Number of Solar Plants': 20,
#   'Installed Capacity (MW)': 118,
#   'Average MW Per Plant': 5.9,
#   'Generation (GWh)': 235},
#  {'State': 'Texas',
#   'Number of Solar Plants': 12,
#   'Installed Capacity (MW)': 187,
#   'Average MW Per Plant': 15.6,
#   'Generation (GWh)': 354},
#  {'State': 'North Carolina',
# ...

# %%
id = 'asdf'
event = {'video_id' : 3}


{json.dumps([id, event['video_id']) : event['time_start']}
# Out:
#   File "<ipython-input-161-d68fd457beb1>", line 5
#     {json.dumps([id, event['video_id']) : event['time_start']}
#                                       ^
# SyntaxError: invalid syntax

# %%
df = pandas.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/solar.csv')
df
# Out:
#             State  Number of Solar Plants  Installed Capacity (MW)  \
# 0      California                     289                     4395
# 1         Arizona                      48                     1078
# 2          Nevada                      11                      238
# 3      New Mexico                      33                      261
# 4        Colorado                      20                      118
# 5           Texas                      12                      187
# 6  North Carolina                     148                      669
# 7        New York                      13                       53
#
#    Average MW Per Plant  Generation (GWh)
# 0                  15.3             10826
# 1                  22.5              2550
# 2                  21.6               557
# 3                   7.9               590
# 4                   5.9               235
# 5                  15.6               354
# 6                   4.5              1162
# ...

# %%
from deep_sort_pytorch import general_utils
from importlib import reload
general_utils = reload(general_utils)




rectangle_l = [[164, 838, 274, 1079], [138, 872, 233, 1079], [100, 912, 178, 1079], [59, 939, 128, 1079]]
ref_loc_l = [[0, 0]]
ref_vec_l = [[1, 1]]
img_shape = [1080, 1920, 3]
general_utils.tracker_similarity_check(ref_loc_l, ref_vec_l, rectangle_l, img_shape, threshold=0.3)
# Out:
# REC CENTERS [[219, 958], [185, 975]]
# REC LIST [[164, 838, 274, 1079], [138, 872, 233, 1079], [100, 912, 178, 1079], [59, 939, 128, 1079]]
# VEC [-0.89442719  0.4472136 ]
# LOC [219, 958]
# REF LOCS: [[0, 0]]
# LOC [219, 958]
# DISTANCES [982.7130812195388]
# REF MAX DIST
# MAX DIST [2202.90717008]
# NORM DIST [982.71308122]
# SIMILARITY METRIC value 0.5539017283316456
# DOING DIRECTION SIMILARITY METRIC
# [[1, 1]] vs [-0.89442719  0.4472136 ]
# similarities [array([0.31622777])]
# DIST SIM 0.5539017283316456
# DIRECTION SIM 0.31622776601683794
# DD METRI VAL 0.4350647471742418
# True

# %%
from deep_sort_pytorch import general_utils
from importlib import reload
general_utils = reload(general_utils)




rectangle_l = [[164, 838, 274, 1079], [138, 872, 233, 1079], [100, 912, 178, 1079], [59, 939, 128, 1079]]
ref_loc_l = [[100, 700]]
ref_vec_l = [[1, 1]]
img_shape = [1080, 1920, 3]
general_utils.tracker_similarity_check(ref_loc_l, ref_vec_l, rectangle_l, img_shape, threshold=0.3)
# Out:
# REC CENTERS [[219, 958], [185, 975]]
# REC LIST [[164, 838, 274, 1079], [138, 872, 233, 1079], [100, 912, 178, 1079], [59, 939, 128, 1079]]
# VEC [-0.89442719  0.4472136 ]
# LOC [219, 958]
# REF LOCS: [[100, 700]]
# LOC [219, 958]
# DISTANCES [284.1214529035075]
# REF MAX DIST
# MAX DIST [1564.86421136]
# NORM DIST [284.1214529]
# SIMILARITY METRIC value 0.8184369922702033
# DOING DIRECTION SIMILARITY METRIC
# [[1, 1]] vs [-0.89442719  0.4472136 ]
# similarities [array([0.31622777])]
# DIST SIM 0.8184369922702033
# DIRECTION SIM 0.31622776601683794
# DD METRI VAL 0.5673323791435206
# True

# %%
from deep_sort_pytorch import general_utils
from importlib import reload
general_utils = reload(general_utils)

rectangle_l = [[164, 838, 274, 1079], [138, 872, 233, 1079], [100, 912, 178, 1079], [59, 939, 128, 1079]]
ref_loc_l = [[100, 700]]
ref_vec_l = [[-1, 1]]
img_shape = [1080, 1920, 3]
general_utils.tracker_similarity_check(ref_loc_l, ref_vec_l, rectangle_l, img_shape, threshold=0.3)
# Out:
# REC CENTERS [[219, 958], [185, 975]]
# REC LIST [[164, 838, 274, 1079], [138, 872, 233, 1079], [100, 912, 178, 1079], [59, 939, 128, 1079]]
# VEC [-0.89442719  0.4472136 ]
# LOC [219, 958]
# REF LOCS: [[100, 700]]
# LOC [219, 958]
# DISTANCES [284.1214529035075]
# REF MAX DIST
# MAX DIST [1564.86421136]
# NORM DIST [284.1214529]
# SIMILARITY METRIC value 0.8184369922702033
# DOING DIRECTION SIMILARITY METRIC
# [[-1, 1]] vs [-0.89442719  0.4472136 ]
# similarities [array([0.9486833])]
# DIST SIM 0.8184369922702033
# DIRECTION SIM 0.9486832980505138
# DD METRI VAL 0.8835601451603585
# True

# %%
x = general_utils.extract_rectangle_centers([rectangle_l[0], rectangle_l[1]])
v = np.array(x[1]) - np.array(x[0])
# Out:
# array([-34,  17])
